# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.groupby('gender').aggregate({'writing score' : 'mean'})
# Out:
#         writing score
# gender
# female      72.467181
# male        63.311203

# %%
df.iloc[0:5, 0:3]
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college
# 2  female        group B             master's degree
# 3    male        group A          associate's degree
# 4    male        group C                some college

# %%
df.iloc[0:7]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
df.head(7)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
titanic = pd.read_csv('https://stepik.org/media/attachments/course/4852/titanic.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.get_dtype_counts()
# Out:
# float64    2
# int64      5
# object     5
# dtype: int64

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
df_with_names = df.iloc[[3, 5, 7, 8, 15]]

# %%
df_with_names.index = ['One', 'Two', 'Three', 'Four', 'Five']

# %%
df_with_names
# Out:
#        gender race/ethnicity parental level of education         lunch  \
# One      male        group A          associate's degree  free/reduced
# Two    female        group B          associate's degree      standard
# Three    male        group B                some college  free/reduced
# Four     male        group D                 high school  free/reduced
# Five   female        group C            some high school      standard
#
#       test preparation course  math score  reading score  writing score
# One                      none          47             57             44
# Two                      none          71             83             78
# Three                    none          40             43             39
# Four                completed          64             64             67
# Five                     none          69             75             78

# %%
df.loc[df.gender == 'male']
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 13    male        group A                some college      standard
# 16    male        group C                 high school      standard
# 18    male        group C             master's degree  free/reduced
# 20    male        group D                 high school      standard
# 22    male        group D                some college      standard
# 24    male        group D           bachelor's degree  free/reduced
# 25    male        group A             master's degree  free/reduced
# ...

# %%
mean_ws = df['writing score'].mean()

# %%
df.loc[df['writing score'] > mean_ws]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 12   female        group B                 high school      standard
# 13     male        group A                some college      standard
# 15   female        group C            some high school      standard
# 16     male        group C                 high school      standard
# 21   female        group B                some college  free/reduced
# 23   female        group C            some high school      standard
# 24     male        group D           bachelor's degree  free/reduced
# ...

# %%
df.loc[(df['writing score'] > mean_ws) & (df.gender == 'female')]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 12   female        group B                 high school      standard
# 15   female        group C            some high school      standard
# 21   female        group B                some college  free/reduced
# 23   female        group C            some high school      standard
# 27   female        group C           bachelor's degree      standard
# 29   female        group D             master's degree      standard
# 30   female        group D                some college      standard
# 36   female        group D          associate's degree      standard
# ...

# %%
# Задание шаг 6 1.5
df.lunch.loc[df.lunch == 'free/reduced'].count() / df.lunch.count()
# Out:
# 0.355

# %%
# Задание шаг 6 1.5
df['lunch'].value_counts(normalize=True)
# Out:
# standard        0.645
# free/reduced    0.355
# Name: lunch, dtype: float64

# %%
# Задание шаг 7 1.5
df.groupby('lunch').aggregate({
    'math score':    ['var', 'mean'],
    'reading score': ['var', 'mean'],
    'writing score': ['var', 'mean']
}).round(2)
# Out:
#              math score        reading score        writing score
#                     var   mean           var   mean           var   mean
# lunch
# free/reduced     229.82  58.92        221.87  64.65        238.20  63.02
# standard         186.42  70.03        191.29  71.65        205.62  70.82

# %%
df.groupby('lunch').agg(['mean', 'var'])
# Out:
#              math score             reading score             writing score  \
#                    mean         var          mean         var          mean
# lunch
# free/reduced  58.921127  229.824270     64.653521  221.871139     63.022535
# standard      70.034109  186.418089     71.654264  191.285560     70.823256
#
#
#                      var
# lunch
# free/reduced  238.202881
# standard      205.620887

# %%
df.columns = df.columns.str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %%
df = df.rename(columns={'race/ethnicity': 'race_ethnicity'})

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %%
df.query("writing_score > 74 & gender == 'female'").head()
# Out:
#     gender race_ethnicity parental_level_of_education     lunch  \
# 1   female        group C                some college  standard
# 2   female        group B             master's degree  standard
# 5   female        group B          associate's degree  standard
# 6   female        group B                some college  standard
# 15  female        group C            some high school  standard
#
#    test_preparation_course  math_score  reading_score  writing_score
# 1                completed          69             90             88
# 2                     none          90             95             93
# 5                     none          71             83             78
# 6                completed          88             95             92
# 15                    none          69             75             78

# %%
thresh = 74
df.query("writing_score > @thresh & gender == 'female'").head()
# Out:
#     gender race_ethnicity parental_level_of_education     lunch  \
# 1   female        group C                some college  standard
# 2   female        group B             master's degree  standard
# 5   female        group B          associate's degree  standard
# 6   female        group B                some college  standard
# 15  female        group C            some high school  standard
#
#    test_preparation_course  math_score  reading_score  writing_score
# 1                completed          69             90             88
# 2                     none          90             95             93
# 5                     none          71             83             78
# 6                completed          88             95             92
# 15                    none          69             75             78

# %%
df[df['parental_level_of_education'].isin(["bachelor's degree", "master's degree"])]
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 14   female        group A             master's degree      standard
# 18     male        group C             master's degree  free/reduced
# 24     male        group D           bachelor's degree  free/reduced
# 25     male        group A             master's degree  free/reduced
# 27   female        group C           bachelor's degree      standard
# 29   female        group D             master's degree      standard
# 32   female        group E             master's degree  free/reduced
# 60     male        group E           bachelor's degree  free/reduced
# 77     male        group A           bachelor's degree      standard
# 79   female        group E             master's degree      standard
# 90   female        group C           bachelor's degree      standard
# ...

# %%
df.filter(like = 'score').head()
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
# Задание шаг 12 1.5 https://stepik.org/lesson/209767/step/12?unit=183265
test_df = pd.read_csv('https://stepik.org/media/attachments/course/4852/column_hell.csv')

# %%
test_df.filter(like='-').head()
# Out:
#     umeca-4  kudbpyw-3       g-3       v-9     fla-6  hwtbyrkp-5
# 0  0.016124   0.430787  0.202407  0.725508  0.305076    0.979296
# 1  0.507115   0.671662  0.864249  0.867818  0.358859    0.160520
# 2  0.003274   0.286411  0.928865  0.719159  0.340235    0.734612
# 3  0.784139   0.863717  0.175446  0.554744  0.049325    0.621132
# 4  0.011265   0.206172  0.044151  0.163643  0.048806    0.437836

# %% [markdown]
# ### Шаг 1.6 агрегации

# %%
df.groupby('gender').mean()
# Out:
#         math_score  reading_score  writing_score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
df.groupby('gender').agg({
    'math_score': 'mean',
    'reading_score': 'mean'
})
# Out:
#         math_score  reading_score
# gender
# female   63.633205      72.608108
# male     68.728216      65.473029

# %%
df.groupby('gender', as_index=False).agg({
    'math_score': 'mean',
    'reading_score': 'mean'
})
# Out:
#    gender  math_score  reading_score
# 0  female   63.633205      72.608108
# 1    male   68.728216      65.473029

# %%
df.sort_values(['gender', 'math_score'], ascending=[True, False]).head()
# Out:
#      gender race_ethnicity parental_level_of_education     lunch  \
# 451  female        group E                some college  standard
# 458  female        group E           bachelor's degree  standard
# 962  female        group E          associate's degree  standard
# 114  female        group E           bachelor's degree  standard
# 263  female        group E                 high school  standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 451                    none         100             92             97
# 458                    none         100            100            100
# 962                    none         100            100            100
# 114               completed          99            100            100
# 263                    none          99             93             90

# %%
df['total_score'] = df.filter(like = 'score').sum(axis=1)

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score
# 0          218
# 1          247
# 2          278
# 3          148
# 4          229

# %%
df.filter(like = 'score').sum(axis=0)
# Out:
# math_score        66089
# reading_score     69169
# writing_score     68054
# total_score      203312
# dtype: int64

# %%
# Задание шага 4 из 1.6
test_df = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv')
test_df.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
test_df.groupby('legs').name.count()
# Out:
# legs
# 0    11
# 2    95
# 4     7
# 6     3
# 8     1
# Name: name, dtype: int64

# %%
# Вариант 2
test_df.legs.value_counts()
# Out:
# 2    95
# 0    11
# 4     7
# 6     3
# 8     1
# Name: legs, dtype: int64

# %%
# Задание шаг 5 1.6
test_df = pd.read_csv('https://stepik.org/media/attachments/course/4852/accountancy.csv')
test_df.head()
# Out:
#    Unnamed: 0 Executor Type  Salary
# 0           0     Pupa    D      63
# 1           1     Pupa    A     158
# 2           2     Pupa    D     194
# 3           3     Pupa    E     109
# 4           4    Loopa    E     184

# %%
test_df.groupby(['Type', 'Executor']).agg({'Salary': 'mean'})
# Out:
#                    Salary
# Type Executor
# A    Loopa      58.000000
#      Pupa      160.833333
# B    Loopa     145.166667
#      Pupa       77.000000
# C    Loopa     154.333333
#      Pupa       74.500000
# D    Loopa     137.714286
#      Pupa      146.500000
# E    Loopa     164.000000
#      Pupa      131.200000
# F    Loopa     238.000000
#      Pupa      136.250000

# %%
# Вариант 2
test_df.pivot_table(values = "Salary", index = "Executor", columns = "Type")
# Out:
# Type               A           B           C           D      E       F
# Executor
# Loopa      58.000000  145.166667  154.333333  137.714286  164.0  238.00
# Pupa      160.833333   77.000000   74.500000  146.500000  131.2  136.25

# %%
# Задание шага 6 из 1.6
test_df = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv')
test_df.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
test_df.groupby(['attack_type', 'primary_attr']).agg({'id': 'count'}).sort_values('id', ascending=False)
# Out:
#                           id
# attack_type primary_attr
# Ranged      int           40
# Melee       str           35
#             agi           19
# Ranged      agi           18
#             str            3
# Melee       int            2

# %%
# Задание шага 7 из 1.6
test_df = pd.read_csv('http://stepik.org/media/attachments/course/4852/algae.csv')
test_df.head()
# Out:
#                species       genus  group   sucrose    alanin   citrate  \
# 0    Fucus_vesiculosus       Fucus  brown  3.001472  3.711498  5.004262
# 1  Saccharina_japonica  Saccharina  brown  6.731070  1.255251  5.621499
# 2       Fucus_serratus       Fucus  brown  3.276870  0.346431  1.216767
# 3      Fucus_distichus       Fucus  brown  6.786996  6.641303  6.423606
# 4    Cladophora_fracta  Cladophora  green  3.861470  1.648450  6.940588
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886

# %%
test_df.groupby('genus').agg({'alanin': ['max', 'mean', 'min']}).round(2).loc['Fucus']
# Out:
# alanin  max     6.64
#         mean    3.57
#         min     0.35
# Name: Fucus, dtype: float64

# %%
test_df.groupby('group').count()
# Out:
#        species  genus  sucrose  alanin  citrate  glucose  oleic_acid
# group
# brown        6      6        6       6        6        6           6
# green        3      3        3       3        3        3           3
# red          1      1        1       1        1        1           1

# %% [markdown]
# ## Урок 1.7

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score
# 0          218
# 1          247
# 2          278
# 3          148
# 4          229

# %%
df.math_score.hist();

# %%
df.plot.scatter(x='math_score', y='reading_score');

# %%
sns.lmplot(x='math_score', y='reading_score', hue='gender', data=df);

# %%
ax = sns.lmplot(x='math_score', y='reading_score', hue='gender', data=df, fit_reg=False);

# %%
ax = sns.lmplot(x='math_score', y='reading_score', hue='gender', data=df, fit_reg=False)
ax.set_xlabels('Math score')
ax.set_ylabels('Reading score');

# %%
test_df = pd.read_csv('https://stepik.org/media/attachments/course/4852/income.csv')
test_df.head()
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
plt.plot(test_df.index, test_df.income)

# %%
test_df.income.plot()

# %%
test_df.plot()

# %%
test_df.plot(kind='line')

# %%
 sns.lineplot(data=test_df)

# %%
sns.lineplot(x=test_df.index, y=test_df.income)

# %%
test_df['income'].plot()

# %%
test_df = pd.read_csv('ds_1_7.txt', sep=' ')

# %%
sns.lmplot(x='x', y='y', data=test_df)

# %%
sns.scatterplot(test_df.x, test_df.y)

# %%
test_df = pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv', index_col=0)
test_df.head()
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
test_df.tail()
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
sns.heatmap(test_df, cmap='viridis');

# %%
test_df = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv', index_col=0, )
test_df.head()
# Out:
#   attack_type  id  legs  localized_name                          name  \
# 0       Melee   1     2       Anti-Mage        npc_dota_hero_antimage
# 1       Melee   2     2             Axe             npc_dota_hero_axe
# 2      Ranged   3     4            Bane            npc_dota_hero_bane
# 3       Melee   4     2     Bloodseeker     npc_dota_hero_bloodseeker
# 4      Ranged   5     2  Crystal Maiden  npc_dota_hero_crystal_maiden
#
#   primary_attr                                              roles
# 0          agi                       ['Carry', 'Escape', 'Nuker']
# 1          str    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2          int        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3          agi  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4          int        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
test_df['num_of_roles'] = test_df.roles.str.count(',') + 1
test_df.groupby(['num_of_roles'])['id'].count().plot()
test_df.head()
# Out:
#   attack_type  id  legs  localized_name                          name  \
# 0       Melee   1     2       Anti-Mage        npc_dota_hero_antimage
# 1       Melee   2     2             Axe             npc_dota_hero_axe
# 2      Ranged   3     4            Bane            npc_dota_hero_bane
# 3       Melee   4     2     Bloodseeker     npc_dota_hero_bloodseeker
# 4      Ranged   5     2  Crystal Maiden  npc_dota_hero_crystal_maiden
#
#   primary_attr                                              roles  \
# 0          agi                       ['Carry', 'Escape', 'Nuker']
# 1          str    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2          int        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3          agi  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4          int        ['Support', 'Disabler', 'Nuker', 'Jungler']
#
#    num_of_roles
# 0             3
# 1             4
# 2             4
# 3             5
# 4             4

# %%
test_df.groupby(['num_of_roles'])['id'].count().plot()

# %%
sns.distplot(test_df.roles.str.count(',') + 1);

# %%
test_df = pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv', index_col=0)
test_df.head()
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
for name in test_df.filter(like='al').columns:
    sns.distplot(test_df[name], label=name, hist=False)

# %%
sns.violinplot(test_df['petal length'], orient = 'v');

# %%
sns.pairplot(test_df.filter(like='al'));

# %%
test_df = pd.DataFrame(data={'type': ['A', 'A', 'B', 'B'], 'value': [10, 14, 12, 23]})
test_df
# Out:
#   type  value
# 0    A     10
# 1    A     14
# 2    B     12
# 3    B     23

# %%
my_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat.csv')
my_stat.head()
# Out:
#    V1    V2 V3   V4
# 0   2  13.0  B  1.0
# 1  -1   7.0  B  1.0
# 2   0  11.0  A  0.0
# 3   2  11.0  A  2.0
# 4   0  10.0  B -1.0

# %%
subset_1 = my_stat.iloc[:10, [0, 2]]
subset_2 = my_stat.drop(index=[0, 4]).filter(regex='[24]')
subset_2.head()
# Out:
#      V2   V4
# 1   7.0  1.0
# 2  11.0  0.0
# 3  11.0  2.0
# 5  11.0  0.0
# 6   9.0  2.0

# %%
my_stat.index not in [0, 4]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-221-1c58d5978e88> in <module>
# ----> 1 my_stat.index not in [0, 4]
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
subset_1 = my_stat.query("V1 > 0 & V3 == 'A'")
subset_2 = my_stat.query("V2 != 10 | V4 >= 1")
# Out:
#    V1    V2 V3   V4
# 0   2  13.0  B  1.0
# 1  -1   7.0  B  1.0
# 2   0  11.0  A  0.0
# 3   2  11.0  A  2.0
# 5   2  11.0  A  0.0

# %%
my_stat['V5'] = my_stat.filter(regex='[14]').sum(axis=1)
my_stat['V6'] = np.log(my_stat.V2)
my_stat.head()
# Out:
#    V1    V2 V3   V4   V5        V6
# 0   2  13.0  B  1.0  3.0  2.564949
# 1  -1   7.0  B  1.0  0.0  1.945910
# 2   0  11.0  A  0.0  0.0  2.397895
# 3   2  11.0  A  2.0  4.0  2.397895
# 4   0  10.0  B -1.0 -1.0  2.302585

# %%
# %timeit my_stat.filter(regex='[14]').sum(axis=1)
# Out:
# 981 µs ± 75.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
my_stat.columns = ['session_value', 'group', 'time', 'n_users']
my_stat.head()
# Out:
#    session_value  group time  n_users
# 0              2   13.0    B      1.0
# 1             -1    7.0    B      1.0
# 2              0   11.0    A      0.0
# 3              2   11.0    A      2.0
# 4              0   10.0    B     -1.0

# %%
my_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat_na.csv')
my_stat.head(10)
# Out:
#    group  n_users  session_value time
# 0    9.0     -9.0            1.0    A
# 1   10.0      8.0            2.0    B
# 2   10.0     -1.0            4.0    A
# 3   10.0     -0.0            0.0    B
# 4    9.0    -15.0           -1.0    B
# 5   11.0    -16.0            0.0    B
# 6   10.0    -12.0            NaN    B
# 7   10.0      1.0            0.0    B
# 8    9.0      3.0            0.0    B
# 9   11.0     11.0            0.0    A

# %%
my_stat['session_value'] = my_stat.session_value.fillna(0)

# %%
my_stat['n_users'] = my_stat['n_users'].mask(my_stat['n_users'] < 0, my_stat.query("n_users > 0").n_users.median())
#my_stat.loc[my_stat.n_users == -0.0, 'n_users'] = 0

# %%
my_stat.head(10)
# Out:
#    group  n_users  session_value time
# 0    9.0      7.5            1.0    A
# 1   10.0      8.0            2.0    B
# 2   10.0      7.5            4.0    A
# 3   10.0      7.5            0.0    B
# 4    9.0      7.5           -1.0    B
# 5   11.0      7.5            0.0    B
# 6   10.0      7.5            0.0    B
# 7   10.0      1.0            0.0    B
# 8    9.0      3.0            0.0    B
# 9   11.0     11.0            0.0    A

# %%
my_stat.groupby('group', as_index=False).session_value.mean().rename(columns={'session_value': 'mean_session_value'})
# Out:
#    group  mean_session_value
# 0    7.0            0.000000
# 1    8.0           -0.294118
# 2    9.0            0.151786
# 3   10.0           -0.047368
# 4   11.0            0.112000
# 5   12.0           -0.382353
# 6   13.0            0.000000
